# %% [markdown]
# # To start the App:
#
#     Need to have Python version 3.13 or higher;
#
#     dependencies = [
#     "requests>=2.32.5",
#     "PyQt5>=5.15.0",
#     "netifaces>=0.11.0"
# ]

# %% [markdown]
# To run, the use of UV is recommended.
# 1. Open the terminal
# 2. Navigate to the project folder

# %%
cd project_folder_name

# %% [markdown]
# 3. Activate the virtual environment
#
# -Windows:

# %%
.\venv\Scripts\activate

# %% [markdown]
# -MacOS/Linux:

# %%
source venv/bin/activate

# %% [markdown]
# 4. Install dependencies

# %%
pip install -r requirements.txt

# %% [markdown]
# 5. Run the application

# %%
python app.py

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# When the application is started, a “Scan Robots” warning message is displayed, showing the Tagi’s IP address for connection.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 1- Battery voltage:
#
# 2- LED Matrix control (change pixels color or input image);
#
# 3- Screen control:
#
# 4- Camera:
#
# 5- Scan Network (To see Tagi's IP address);
#
# 6- Audio control:
#
# 7- Speech to text (Write text to be converted into speech);
#
# 8- Servo motor control (Adjust position, enable/disable torque);
#
# 9- Motor Limits:
#
# 10- Multimedia in use:
#
# 11- Touch sensor control (touch sensor values);
#
# 12- Enable Behaviours;
